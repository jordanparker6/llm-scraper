# %%
import sys
from dotenv import load_dotenv
sys.path.append('..')
load_dotenv()
# Out:
# True

# %%
from src import LLMScraper, ScraperConfig
from src.browser import get_browser
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI()
config = ScraperConfig.from_env()
config.log_html = False
browser = get_browser()
scraper = LLMScraper(llm, browser, config)

output = scraper.scrape(
    url="https://www.linkedin.com/in/jordan-parker-092a7258/", 
    keys=["name", "profile", "location", "education", "experience", "skills"]
)
output
# Out:
# 2023-10-09 15:28:22 [debug    ] html                           data=<html lang="en"><head>
# <meta content="public_profile_v3_desktop" name="pageKey"/>
# <meta content="nonCanonical" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1724" data-browser-id="cac1d2ef-d07f-4e0e-8e4b-4cad8fd019bd" data-call-tree-id="AAYHTZfX870R72sQUMFm7w==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-is-li-sugr-tracking-enabled="" data-logout-url="/uas/logout" data-member-id="0" data-msafdf-lib="https://static.licdn.com/aero-v1/sc/h/80ndnja80f2uvg4l8sj2su82m" data-multiproduct-name="public-profile-frontend" data-page-instance="urn:li:page:public_profile_v3;ij8FEG60QOCS9JkKVcf6mQ==" data-service-name="public-profile-frontend" id="config"/>
# <link href="https://au.linkedin.com/in/jordan-parker-092a7258" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# ...
